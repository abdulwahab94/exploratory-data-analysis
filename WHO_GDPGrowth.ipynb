# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulwahab94/exploratory-data-analysis/blob/main/WHO_GDPGrowth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('Life Expectancy Data.csv')
#df.head()
print(len(df))
# Out:
# 2938

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
#df=df.head(50)

# %%
N=len(df)
colors = np.random.rand(N)
plt.scatter(df['Life expectancy '],df['Country'], c=colors, s=50, alpha=1)
plt.xlabel('Life expectancy ')
plt.ylabel('Country')
plt.title('Life expectancy vs Country')
plt.show()

# %%
N=len(df)
colors = np.random.rand(N)
plt.scatter(df['GDP'],df['Country'], c=colors, s=50, alpha=1)
plt.xlabel('GDP')
plt.ylabel('Country')
plt.title('GDP vs Country')
plt.show()

# %%
GDP_per_capita=df['GDP']/df['Population']
df['GDP_per_capita']=GDP_per_capita
#sns.scatterplot(x='GDP_per_capita',y='Life expectancy ',data=df)
#sns.lmplot(x='GDP_per_capita',y='Life expectancy ',data=df)
#plt.show()
df.head(20)
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 0   Afghanistan  2015  Developing              65.0            263.0
# 1   Afghanistan  2014  Developing              59.9            271.0
# 2   Afghanistan  2013  Developing              59.9            268.0
# 3   Afghanistan  2012  Developing              59.5            272.0
# 4   Afghanistan  2011  Developing              59.2            275.0
# 5   Afghanistan  2010  Developing              58.8            279.0
# 6   Afghanistan  2009  Developing              58.6            281.0
# 7   Afghanistan  2008  Developing              58.1            287.0
# 8   Afghanistan  2007  Developing              57.5            295.0
# 9   Afghanistan  2006  Developing              57.3            295.0
# 10  Afghanistan  2005  Developing              57.3            291.0
# 11  Afghanistan  2004  Developing              57.0            293.0
# 12  Afghanistan  2003  Developing              56.7            295.0
# ...

# %%
#lets check the GDP growth of Afghanistan over two decades
df_Afghanistan=df[df['Country']=='Afghanistan']
df_Pakistan=df[df['Country']=='Pakistan']
df_Bangladesh=df[df['Country']=='Bangladesh']
df_India=df[df['Country']=='India']
df_Srilanka=df[df['Country']=='Sri Lanka']
plt.plot(df_Afghanistan['Year'],df_Afghanistan['GDP'],label='Afghanistan')
plt.plot(df_Pakistan['Year'],df_Pakistan['GDP'],label='Pakistan')
plt.plot(df_Bangladesh['Year'],df_Bangladesh['GDP'],label='Bangladesh')
plt.plot(df_India['Year'],df_India['GDP'],label='India')
plt.plot(df_Srilanka['Year'],df_Srilanka['GDP'],label='Srilanka')
plt.title('GDP growth of South Asian Countries')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.legend()
plt.show()

# %%
#GDP per capita comparison of South Asian Countries
plt.plot(df_Afghanistan['Year'],GDP_per_capita_Afghanistan,label='Afghanistan')
plt.plot(df_Pakistan['Year'],df_Pakistan['GDP_per_capita'],label='Pakistan')
plt.plot(df_Bangladesh['Year'],df_Bangladesh['GDP_per_capita'],label='Bangladesh')
plt.plot(df_India['Year'],df_India['GDP_per_capita'],label='India')
plt.plot(df_Srilanka['Year'],df_Srilanka['GDP_per_capita'],label='Srilanka')
plt.title('GDP per capita growth of South Asian Countries')
plt.xlabel('Year')
plt.ylabel('GDP per capita')
plt.legend()
plt.show()
